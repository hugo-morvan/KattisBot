# %%
import os
from dotenv import load_dotenv
load_dotenv()
user = os.getenv("USER")
password = os.getenv("PASSWORD")

# %%
from autokattis import OpenKattis

kt = OpenKattis(user, password)
# Out:
# [login] Candidate username(s): ['hugo-morvan']
# [login] Successfully logged in to Kattis as hugo-morvan!
# [database] Listed all available languages!
# [database] Listed all 208 available countries!
# [database] Listed all 3940 available universities!

# %%
help(kt.problems)

# %%
kt.plot_problems(show_partial=True, show_solved=True, show_tried=True, show_untried=True)

# %%
kt.problem('sequences')
# Out:
# [{'id': 'sequences',
#   'text': 'You are given a sequence, in the form of a string with\n    characters ‘0’, ‘1’, and ‘?’ only.\n    Suppose there are $k$\n    ‘?’s. Then there are $2^ k$ ways to replace each\n    ‘?’ by a ‘0’ or a ‘1’, giving\n    $2^ k$ different 0-1\n    sequences (0-1 sequences are sequences with only zeroes and\n    ones).\nFor each 0-1 sequence, define its number of inversions as\n    the minimum number of adjacent swaps required to sort the\n    sequence in non-decreasing order. In this problem, the sequence\n    is sorted in non-decreasing order precisely when all the zeroes\n    occur before all the ones. For example, the sequence 11010 has $5$ inversions. We can sort it by the\n    following moves: 11010 $\\rightarrow $ 11001 $\\rightarrow $ 10101 $\\rightarrow $ 01101 $\\rightarrow $ 01011 $\\rightarrow $ 00111.\nFind the sum of the number of inversions of the $2^ k$ sequences, modulo $1\\, 000\\, 000\\, 007$ ($10^9 + 7$).\nInput\nThe first and only line of input contains the input string,\n    consisting of characters ‘0’,\n    ‘1’, and ‘?’ only, and the input string has between\n    $1$ to $500\\, 000$ characters, inclusive.\nOutput\nOutput an integer indicating the aforementioned number of\n    inversions modulo $1\\, 000\\,\n    000\\, 007$.\n\n\nSample Input 1\nSample Output 1\n\n\n\n\n?0?\n\n\n\n\n3',
#   'cpu': '1 second',
#   'memory': '1024 MB',
#   'difficulty': 5.4,
#   'category': 'Medium',
#   'author': 'Tung Kam Chuen',
#   'source': 'Hong Kong Regional Online Preliminary 2016',
#   'files': {},
#   'statistics': {'Bash': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Chenzhang Hu',
#        'username': 'hcz',
#        'runtime': 0.12,
#        'date': '2024-04-16 16:50:25'}],
#      'description': 'The 10 fastest solutions in Bash'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Chenzhang Hu',
#        'username': 'hcz',
#        'length': 5,
#        'date': '2024-04-16 16:50:25'}],
#      'description': 'The 10 shortest solutions in Bash'}},
#    'C': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Hidden user',
#        'username': None,
#        'runtime': 0.0,
#        'date': '2019-06-27 22:26:37'},
#       {'rank': 2,
#        'name': 'Kenneth Langedal',
#        'username': 'kennethlangedal',
#        'runtime': 0.0,
#        'date': '2022-12-08 16:54:31'},
#       {'rank': 3,
#        'name': 'Hjalti Isleifsson',
#        'username': 'hjalti-isleifsson',
#        'runtime': 0.0,
#        'date': '2023-02-21 21:21:02'},
#       {'rank': 4,
#        'name': 'How Si Yu',
#        'username': 'forget',
#        'runtime': 0.01,
#        'date': '2016-10-13 15:57:50'},
#       {'rank': 5,
#        'name': 'Hidden user',
#        'username': None,
#        'runtime': 0.01,
#        'date': '2016-10-14 08:08:15'},
#       {'rank': 6,
#        'name': 'Samuel Wrååk',
#        'username': 'samuel-wraak',
#        'runtime': 0.01,
#        'date': '2016-11-20 21:42:43'},
#       {'rank': 7,
#        'name': 'Bengt Werstén',
#        'username': 'bengt-wersten',
#        'runtime': 0.01,
#        'date': '2017-06-29 10:52:22'},
#       {'rank': 8,
#        'name': 'Riccardo Sven Risuleo',
#        'username': 'riccardo-sven-risuleo',
#        'runtime': 0.01,
#        'date': '2017-07-21 08:23:00'},
#       {'rank': 9,
#        'name': '李瀚杰',
#        'username': '9zct9xeb',
#        'runtime': 0.01,
#        'date': '2017-08-04 11:27:28'},
#       {'rank': 10,
#        'name': 'John Paul Hanson',
#        'username': 'john-paul-hanson-7460',
#        'runtime': 0.01,
#        'date': '2017-09-19 17:14:36'}],
#      'description': 'The 10 fastest solutions in C'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Lawry Sorenson',
#        'username': 'pipoika',
#        'length': 212,
#        'date': '2022-12-15 01:56:46'},
#       {'rank': 2,
#        'name': 'Tree Librarian',
#        'username': 'tree-librarian',
#        'length': 467,
#        'date': '2024-07-25 03:48:00'},
#       {'rank': 3,
#        'name': 'Reuben',
#        'username': 'reuben.g',
#        'length': 497,
#        'date': '2023-07-19 13:26:09'},
#       {'rank': 4,
#        'name': 'Elias Nodland',
#        'username': 'elias-nodland',
#        'length': 503,
#        'date': '2019-07-28 14:50:10'},
#       {'rank': 5,
#        'name': 'Adrian Gugyin',
#        'username': 'n3u2o',
#        'length': 606,
#        'date': '2020-10-03 22:41:23'},
#       {'rank': 6,
#        'name': 'Tran Vu Hung (K18 CT)',
#        'username': 'tran-vu-hung--k18-ct-',
#        'length': 640,
#        'date': '2023-08-14 09:10:01'},
#       {'rank': 7,
#        'name': 'Shiyi Du',
#        'username': 'shiyi-du',
#        'length': 665,
#        'date': '2018-10-21 23:08:23'},
#       {'rank': 8,
#        'name': 'Leonardo Gagliardoni',
#        'username': 'feuergas',
#        'length': 669,
#        'date': '2021-11-22 14:46:33'},
#       {'rank': 9,
#        'name': 'Bengt Werstén',
#        'username': 'bengt-wersten',
#        'length': 708,
#        'date': '2017-06-29 10:52:22'},
#       {'rank': 10,
#        'name': 'Hidden user',
#        'username': None,
#        'length': 715,
#        'date': '2019-09-02 22:22:09'}],
#      'description': 'The 10 shortest solutions in C'}},
#    'C#': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Anton Kuzin',
#        'username': 'anton-kuzin',
#        'runtime': 0.03,
#        'date': '2022-04-18 17:39:20'},
#       {'rank': 2,
#        'name': 'Tom Hagelskjær',
#        'username': 'tom-hagelskjaer',
#        'runtime': 0.03,
#        'date': '2022-12-15 11:12:08'},
#       {'rank': 3,
#        'name': 'Klas Björkqvist',
#        'username': 'klas-bjorkqvist',
#        'runtime': 0.04,
#        'date': '2019-10-20 21:10:07'},
#       {'rank': 4,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'runtime': 0.04,
#        'date': '2020-05-20 12:35:02'},
#       {'rank': 5,
#        'name': 'Marcos Kirchner',
#        'username': 'marcos-kirchner',
#        'runtime': 0.04,
#        'date': '2021-07-28 01:15:20'},
#       {'rank': 6,
#        'name': 'Alexander Z.',
#        'username': 'alexander-z-',
#        'runtime': 0.04,
#        'date': '2022-07-02 18:41:10'},
#       {'rank': 7,
#        'name': 'Kasper Kabell',
#        'username': 'kabbitron',
#        'runtime': 0.04,
#        'date': '2023-01-31 00:13:19'},
#       {'rank': 8,
#        'name': 'Patrik Blomqvist',
#        'username': 'blomman',
#        'runtime': 0.05,
#        'date': '2017-01-26 10:27:25'},
#       {'rank': 9,
#        'name': 'Seyed Sadjad Mirtaqi',
#        'username': 'seyed-sadjad-mirtaqi',
#        'runtime': 0.05,
#        'date': '2019-02-16 11:36:11'},
#       {'rank': 10,
#        'name': 'Andreas Hansson',
#        'username': 'adron',
#        'runtime': 0.05,
#        'date': '2019-03-08 12:01:54'}],
#      'description': 'The 10 fastest solutions in C#'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Tom Hagelskjær',
#        'username': 'tom-hagelskjaer',
#        'length': 287,
#        'date': '2022-12-16 16:10:37'},
#       {'rank': 2,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'length': 882,
#        'date': '2020-05-20 12:35:02'},
#       {'rank': 3,
#        'name': 'Andreas Hansson',
#        'username': 'adron',
#        'length': 1109,
#        'date': '2019-03-08 12:01:54'},
#       {'rank': 4,
#        'name': 'Sano Gharzani',
#        'username': 'sano-gharzani',
#        'length': 1156,
#        'date': '2023-09-10 12:30:25'},
#       {'rank': 5,
#        'name': 'Nicolas Enjalbert',
#        'username': 'nicolas-enjalbert',
#        'length': 1292,
#        'date': '2019-08-23 14:05:23'},
#       {'rank': 6,
#        'name': 'Alexander Z.',
#        'username': 'alexander-z-',
#        'length': 1305,
#        'date': '2022-07-02 18:41:10'},
#       {'rank': 7,
#        'name': 'Marcos Kirchner',
#        'username': 'marcos-kirchner',
#        'length': 1383,
#        'date': '2021-07-28 01:15:20'},
#       {'rank': 8,
#        'name': 'mustata_lui_dragnea',
#        'username': 'mustata-lui-dragnea',
#        'length': 1401,
#        'date': '2020-10-21 08:10:07'},
#       {'rank': 9,
#        'name': 'Hakan Yurt',
#        'username': 'obihakanobi',
#        'length': 1446,
#        'date': '2023-03-29 14:24:42'},
#       {'rank': 10,
#        'name': 'Klas Björkqvist',
#        'username': 'klas-bjorkqvist',
#        'length': 1454,
#        'date': '2019-10-20 21:10:07'}],
#      'description': 'The 10 shortest solutions in C#'}},
#    'C++': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Kuanze Ren',
#        'username': '111qqz',
#        'runtime': 0.01,
#        'date': '2016-09-10 08:07:54'},
#       {'rank': 2,
#        'name': 'Zhengjie Xu',
#        'username': 'zhengjie-xu',
#        'runtime': 0.01,
#        'date': '2016-09-10 08:09:29'},
#       {'rank': 3,
#        'name': 'Zixiong Su',
#        'username': 'zixiong-su-0823',
#        'runtime': 0.01,
#        'date': '2016-09-10 08:19:45'},
#       {'rank': 4,
#        'name': 'Hongchuan Sun',
#        'username': 'hongchuan-sun-7845',
#        'runtime': 0.01,
#        'date': '2016-09-10 08:23:29'},
#       {'rank': 5,
#        'name': 'Weiming Liu',
#        'username': 'weiming-liu-5269',
#        'runtime': 0.01,
#        'date': '2016-09-10 08:43:05'},
#       {'rank': 6,
#        'name': 'Shiyuan Zhang',
#        'username': 'poetry',
#        'runtime': 0.01,
#        'date': '2016-09-10 09:05:52'},
#       {'rank': 7,
#        'name': 'Zongming Yin',
#        'username': 'zongming-yin-4311',
#        'runtime': 0.01,
#        'date': '2016-09-10 09:22:45'},
#       {'rank': 8,
#        'name': 'Zhang Shaoang',
#        'username': 'zhangshaoang',
#        'runtime': 0.01,
#        'date': '2016-09-10 09:25:56'},
#       {'rank': 9,
#        'name': 'Jiarui Luo',
#        'username': 'jiarui-luo-1585',
#        'runtime': 0.01,
#        'date': '2016-09-10 09:43:27'},
#       {'rank': 10,
#        'name': 'Chen Rui',
#        'username': 'chen-rui1',
#        'runtime': 0.01,
#        'date': '2016-09-10 09:47:28'}],
#      'description': 'The 10 fastest solutions in C++'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Lucas Ethington',
#        'username': 'lucas-ethington',
#        'length': 289,
#        'date': '2024-03-25 00:56:36'},
#       {'rank': 2,
#        'name': 'Monlin Zhi',
#        'username': 'ayash',
#        'length': 339,
#        'date': '2017-06-12 12:09:54'},
#       {'rank': 3,
#        'name': 'Christian Yongwhan Lim',
#        'username': 'yongwhan',
#        'length': 345,
#        'date': '2023-06-02 23:17:39'},
#       {'rank': 4,
#        'name': 'anonymous',
#        'username': 'thebes',
#        'length': 396,
#        'date': '2018-01-08 23:23:25'},
#       {'rank': 5,
#        'name': 'Đậu Huy Minh',
#        'username': 'dauhuyminh',
#        'length': 397,
#        'date': '2022-10-16 17:21:25'},
#       {'rank': 6,
#        'name': 'Luca Cavalleri',
#        'username': 'lukecavabarrett',
#        'length': 411,
#        'date': '2018-03-01 10:30:38'},
#       {'rank': 7,
#        'name': 'Johan Wind',
#        'username': 'johan',
#        'length': 416,
#        'date': '2017-04-20 19:35:39'},
#       {'rank': 8,
#        'name': 'Hidden user',
#        'username': None,
#        'length': 432,
#        'date': '2016-11-13 11:07:39'},
#       {'rank': 9,
#        'name': 'Georgios Iatrou',
#        'username': 'georgios-iatrou',
#        'length': 456,
#        'date': '2017-04-12 23:58:34'},
#       {'rank': 10,
#        'name': 'Jordan Lamkin',
#        'username': 'davidj',
#        'length': 457,
#        'date': '2017-12-16 07:44:35'}],
#      'description': 'The 10 shortest solutions in C++'}},
#    'Common Lisp': {'fastest': {'ranklist': [{'rank': 1,
#        'name': '云中客',
#        'username': 'shzjf24s',
#        'runtime': 0.14,
#        'date': '2019-10-11 17:59:06'}],
#      'description': 'The 10 fastest solutions in Common Lisp'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': '云中客',
#        'username': 'shzjf24s',
#        'length': 1328,
#        'date': '2019-10-12 07:07:17'}],
#      'description': 'The 10 shortest solutions in Common Lisp'}},
#    'Go': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Norbert Voelker',
#        'username': 'norbs',
#        'runtime': 0.02,
#        'date': '2023-03-16 00:41:25'},
#       {'rank': 2,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'runtime': 0.09,
#        'date': '2020-05-20 13:11:48'},
#       {'rank': 3,
#        'name': 'Kev Burns',
#        'username': 'kev-burns',
#        'runtime': 0.09,
#        'date': '2021-06-25 07:44:38'},
#       {'rank': 4,
#        'name': 'Krzysztof Gibuła',
#        'username': 'krzysiekg',
#        'runtime': 0.09,
#        'date': '2022-04-11 01:10:06'},
#       {'rank': 5,
#        'name': 'Reuben',
#        'username': 'reuben.g',
#        'runtime': 0.56,
#        'date': '2023-07-17 19:46:37'},
#       {'rank': 6,
#        'name': 'Kalle Johansson',
#        'username': 'kal-elx',
#        'runtime': 0.56,
#        'date': '2023-09-27 17:11:33'},
#       {'rank': 7,
#        'name': 'Nicklas Østerberg',
#        'username': 'nicklasbns',
#        'runtime': 0.65,
#        'date': '2023-09-26 14:12:08'},
#       {'rank': 8,
#        'name': 'Austin Habedank',
#        'username': 'austin-habedank-4986',
#        'runtime': 0.87,
#        'date': '2021-05-03 00:01:31'}],
#      'description': 'The 10 fastest solutions in Go'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Reuben',
#        'username': 'reuben.g',
#        'length': 446,
#        'date': '2023-07-17 19:46:37'},
#       {'rank': 2,
#        'name': 'Kalle Johansson',
#        'username': 'kal-elx',
#        'length': 469,
#        'date': '2023-09-27 17:11:33'},
#       {'rank': 3,
#        'name': 'Kev Burns',
#        'username': 'kev-burns',
#        'length': 510,
#        'date': '2021-06-25 07:44:38'},
#       {'rank': 4,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'length': 620,
#        'date': '2020-05-20 13:11:48'},
#       {'rank': 5,
#        'name': 'Krzysztof Gibuła',
#        'username': 'krzysiekg',
#        'length': 639,
#        'date': '2022-04-11 01:10:06'},
#       {'rank': 6,
#        'name': 'Norbert Voelker',
#        'username': 'norbs',
#        'length': 1362,
#        'date': '2023-03-16 01:02:58'},
#       {'rank': 7,
#        'name': 'Nicklas Østerberg',
#        'username': 'nicklasbns',
#        'length': 1375,
#        'date': '2023-09-26 14:12:08'},
#       {'rank': 8,
#        'name': 'Austin Habedank',
#        'username': 'austin-habedank-4986',
#        'length': 1379,
#        'date': '2021-05-03 00:01:31'}],
#      'description': 'The 10 shortest solutions in Go'}},
#    'Haskell': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Stevenald Buscemiton',
#        'username': 'stevenald-buscemiton',
#        'runtime': 0.02,
#        'date': '2024-09-01 04:49:21'},
#       {'rank': 2,
#        'name': 'Lars Corbijn',
#        'username': 'lars-corbijn',
#        'runtime': 0.03,
#        'date': '2016-10-15 14:43:30'},
#       {'rank': 3,
#        'name': 'Juan Miguel Vilar',
#        'username': 'jvilar',
#        'runtime': 0.03,
#        'date': '2020-07-07 11:17:18'},
#       {'rank': 4,
#        'name': 'Aliaksey Artamonau',
#        'username': 'aartamonau',
#        'runtime': 0.04,
#        'date': '2020-05-11 04:35:40'},
#       {'rank': 5,
#        'name': 'Udo Stenzel',
#        'username': 'udo-stenzel',
#        'runtime': 0.04,
#        'date': '2022-06-11 17:54:17'},
#       {'rank': 6,
#        'name': 'Olle Eriksson',
#        'username': 'olle-eriksson1',
#        'runtime': 0.05,
#        'date': '2019-08-02 00:35:58'},
#       {'rank': 7,
#        'name': 'Thomas Almestad',
#        'username': 'allmeta',
#        'runtime': 0.05,
#        'date': '2020-04-02 23:23:25'},
#       {'rank': 8,
#        'name': 'Noa Torstensvik',
#        'username': 'k4rfwci5',
#        'runtime': 0.07,
#        'date': '2023-01-03 22:25:21'},
#       {'rank': 9,
#        'name': 'How Si Wei',
#        'username': 'howsiwei',
#        'runtime': 0.08,
#        'date': '2018-11-30 21:32:44'},
#       {'rank': 10,
#        'name': '云中客',
#        'username': 'shzjf24s',
#        'runtime': 0.08,
#        'date': '2019-10-11 18:29:07'}],
#      'description': 'The 10 fastest solutions in Haskell'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Juan Miguel Vilar',
#        'username': 'jvilar',
#        'length': 162,
#        'date': '2023-07-30 13:01:58'},
#       {'rank': 2,
#        'name': 'Reuben',
#        'username': 'reuben.g',
#        'length': 290,
#        'date': '2023-07-17 08:40:11'},
#       {'rank': 3,
#        'name': 'Noa Torstensvik',
#        'username': 'k4rfwci5',
#        'length': 427,
#        'date': '2023-01-05 13:29:03'},
#       {'rank': 4,
#        'name': 'Hidden user',
#        'username': None,
#        'length': 520,
#        'date': '2019-10-22 07:24:22'},
#       {'rank': 5,
#        'name': 'Olle Eriksson',
#        'username': 'olle-eriksson1',
#        'length': 546,
#        'date': '2019-08-02 00:35:58'},
#       {'rank': 6,
#        'name': 'Thomas Almestad',
#        'username': 'allmeta',
#        'length': 556,
#        'date': '2020-04-02 23:23:25'},
#       {'rank': 7,
#        'name': 'Stevenald Buscemiton',
#        'username': 'stevenald-buscemiton',
#        'length': 775,
#        'date': '2024-08-31 16:36:06'},
#       {'rank': 8,
#        'name': 'Brandon Mabey',
#        'username': 'brandon-mabey-9030',
#        'length': 823,
#        'date': '2017-06-27 21:31:41'},
#       {'rank': 9,
#        'name': 'Lars Corbijn',
#        'username': 'lars-corbijn',
#        'length': 846,
#        'date': '2016-10-15 14:43:30'},
#       {'rank': 10,
#        'name': 'Aliaksey Artamonau',
#        'username': 'aartamonau',
#        'length': 971,
#        'date': '2020-05-10 08:28:27'}],
#      'description': 'The 10 shortest solutions in Haskell'}},
#    'Java': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Hà Minh Ngọc',
#        'username': 'haminhngoc',
#        'runtime': 0.06,
#        'date': '2016-12-13 09:24:05'},
#       {'rank': 2,
#        'name': 'Bjørn Dons',
#        'username': 'guardsman-bob',
#        'runtime': 0.08,
#        'date': '2018-11-11 05:55:14'},
#       {'rank': 3,
#        'name': 'Micah Stairs',
#        'username': 'micah.stairs',
#        'runtime': 0.09,
#        'date': '2016-09-21 02:10:13'},
#       {'rank': 4,
#        'name': 'Alex Coleman',
#        'username': 'alexrcoleman',
#        'runtime': 0.09,
#        'date': '2018-10-17 03:50:21'},
#       {'rank': 5,
#        'name': 'Martijn Muijsers',
#        'username': 'martijn',
#        'runtime': 0.1,
#        'date': '2016-11-02 15:24:57'},
#       {'rank': 6,
#        'name': 'Alan Evans',
#        'username': 'alan-evans',
#        'runtime': 0.1,
#        'date': '2017-03-03 12:44:58'},
#       {'rank': 7,
#        'name': 'Måns Magnusson',
#        'username': 'exoji2e',
#        'runtime': 0.1,
#        'date': '2017-03-27 19:34:14'},
#       {'rank': 8,
#        'name': 'Olav Røthe Bakken',
#        'username': 'olav-rothe-bakken',
#        'runtime': 0.1,
#        'date': '2017-10-19 12:15:49'},
#       {'rank': 9,
#        'name': 'Krystian Wojcicki',
#        'username': 'krystian-wojcicki',
#        'runtime': 0.1,
#        'date': '2017-11-08 02:53:50'},
#       {'rank': 10,
#        'name': 'Crystal Sharpe',
#        'username': 'crystal-sharpe',
#        'runtime': 0.1,
#        'date': '2020-07-18 04:00:21'}],
#      'description': 'The 10 fastest solutions in Java'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Brennan Cleland',
#        'username': 'eternaldx',
#        'length': 514,
#        'date': '2023-08-18 00:56:03'},
#       {'rank': 2,
#        'name': 'Shawn Zhong',
#        'username': 'shawnzhong',
#        'length': 604,
#        'date': '2017-09-10 22:36:15'},
#       {'rank': 3,
#        'name': 'Hidden user',
#        'username': None,
#        'length': 636,
#        'date': '2018-10-26 23:38:18'},
#       {'rank': 4,
#        'name': 'Hidden user',
#        'username': None,
#        'length': 682,
#        'date': '2023-11-02 02:00:32'},
#       {'rank': 5,
#        'name': 'Sam Zheng',
#        'username': 'sam-zheng',
#        'length': 683,
#        'date': '2021-10-29 03:21:44'},
#       {'rank': 6,
#        'name': 'Antony Lee',
#        'username': 'antony-lee',
#        'length': 715,
#        'date': '2018-10-04 16:58:42'},
#       {'rank': 7,
#        'name': 'Martin Vatshelle',
#        'username': 'martin-vatshelle',
#        'length': 744,
#        'date': '2019-11-01 23:59:40'},
#       {'rank': 8,
#        'name': 'Michael  Liu',
#        'username': 'michael--liu',
#        'length': 748,
#        'date': '2018-05-20 21:54:58'},
#       {'rank': 9,
#        'name': 'Wei Shen Ooi',
#        'username': 'wei-shen-ooi',
#        'length': 762,
#        'date': '2023-03-02 08:33:36'},
#       {'rank': 10,
#        'name': 'Daniel West',
#        'username': 'daniel-west',
#        'length': 764,
#        'date': '2018-05-16 15:08:02'}],
#      'description': 'The 10 shortest solutions in Java'}},
#    'JavaScript (Node.js)': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Archangel ZA',
#        'username': 'archangel-za',
#        'runtime': 0.11,
#        'date': '2023-05-16 18:14:35'},
#       {'rank': 2,
#        'name': 'Shize Li',
#        'username': 'shize-li',
#        'runtime': 0.12,
#        'date': '2023-03-17 01:13:29'},
#       {'rank': 3,
#        'name': 'WILLIAM MAURICIO GIRALDO MURILLO',
#        'username': 'william-mauricio-giraldo-murillo',
#        'runtime': 0.19,
#        'date': '2023-04-20 14:11:19'},
#       {'rank': 4,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'runtime': 0.44,
#        'date': '2020-05-20 12:00:27'},
#       {'rank': 5,
#        'name': 'Matzuka',
#        'username': 'matzuka',
#        'runtime': 0.45,
#        'date': '2021-03-02 23:42:04'}],
#      'description': 'The 10 fastest solutions in JavaScript (Node.js)'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Matzuka',
#        'username': 'matzuka',
#        'length': 555,
#        'date': '2021-03-02 23:42:04'},
#       {'rank': 2,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'length': 687,
#        'date': '2020-05-20 12:00:27'},
#       {'rank': 3,
#        'name': 'Shize Li',
#        'username': 'shize-li',
#        'length': 700,
#        'date': '2023-03-17 01:13:29'},
#       {'rank': 4,
#        'name': 'Archangel ZA',
#        'username': 'archangel-za',
#        'length': 704,
#        'date': '2023-05-16 18:14:35'},
#       {'rank': 5,
#        'name': 'WILLIAM MAURICIO GIRALDO MURILLO',
#        'username': 'william-mauricio-giraldo-murillo',
#        'length': 993,
#        'date': '2023-04-20 14:11:19'}],
#      'description': 'The 10 shortest solutions in JavaScript (Node.js)'}},
#    'JavaScript (SpiderMonkey)': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Christian Cederquist',
#        'username': 'christian-cederquist',
#        'runtime': 0.05,
#        'date': '2023-02-26 09:54:48'},
#       {'rank': 2,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'runtime': 0.08,
#        'date': '2020-05-20 11:52:02'},
#       {'rank': 3,
#        'name': 'Aron Kornhall',
#        'username': 'kornhall',
#        'runtime': 0.12,
#        'date': '2016-10-04 18:51:29'}],
#      'description': 'The 10 fastest solutions in JavaScript (SpiderMonkey)'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Christian Cederquist',
#        'username': 'christian-cederquist',
#        'length': 411,
#        'date': '2023-02-26 09:54:48'},
#       {'rank': 2,
#        'name': 'Sergei Blinov',
#        'username': 'sergei-blinov',
#        'length': 487,
#        'date': '2020-05-20 11:52:02'},
#       {'rank': 3,
#        'name': 'Aron Kornhall',
#        'username': 'kornhall',
#        'length': 1327,
#        'date': '2016-10-04 18:51:29'}],
#      'description': 'The 10 shortest solutions in JavaScript (SpiderMonkey)'}},
#    'Kotlin': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Benjamin Ye',
#        'username': 'glassbricks',
#        'runtime': 0.21,
#        'date': '2022-02-10 04:35:11'},
#       {'rank': 2,
#        'name': 'Lam Gia Thuan',
#        'username': 'duckladydinh',
#        'runtime': 0.23,
#        'date': '2017-11-07 02:57:14'},
#       {'rank': 3,
#        'name': 'Jacob Huebner',
#        'username': 'hakiobo',
#        'runtime': 0.23,
#        'date': '2021-05-11 08:19:26'},
#       {'rank': 4,
#        'name': 'Jonathan Soo',
#        'username': 'jonathan-soo',
#        'runtime': 0.24,
#        'date': '2020-01-26 08:46:59'},
#       {'rank': 5,
#        'name': 'Adam Rankin',
#        'username': 'adam-rankin',
#        'runtime': 0.32,
#        'date': '2023-10-28 20:17:08'},
#       {'rank': 6,
#        'name': 'Lin Lee',
#        'username': 'lin-lee',
#        'runtime': 0.34,
#        'date': '2019-08-09 15:37:39'},
#       {'rank': 7,
#        'name': 'Dương Vũ Thụy Vy',
#        'username': 'duongvuthuyvy',
#        'runtime': 0.35,
#        'date': '2022-07-06 18:51:15'},
#       {'rank': 8,
#        'name': 'Mike Nguyen',
#        'username': 'noob-programmer',
#        'runtime': 0.39,
#        'date': '2022-02-11 04:54:28'}],
#      'description': 'The 10 fastest solutions in Kotlin'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Dương Vũ Thụy Vy',
#        'username': 'duongvuthuyvy',
#        'length': 523,
#        'date': '2022-07-06 18:51:15'},
#       {'rank': 2,
#        'name': 'Adam Rankin',
#        'username': 'adam-rankin',
#        'length': 577,
#        'date': '2023-10-28 20:17:08'},
#       {'rank': 3,
#        'name': 'Lin Lee',
#        'username': 'lin-lee',
#        'length': 749,
#        'date': '2019-08-09 15:37:39'},
#       {'rank': 4,
#        'name': 'Jacob Huebner',
#        'username': 'hakiobo',
#        'length': 1233,
#        'date': '2021-05-11 08:19:26'},
#       {'rank': 5,
#        'name': 'Mike Nguyen',
#        'username': 'noob-programmer',
#        'length': 2590,
#        'date': '2022-02-11 04:54:28'},
#       {'rank': 6,
#        'name': 'Lam Gia Thuan',
#        'username': 'duckladydinh',
#        'length': 2619,
#        'date': '2017-11-07 02:57:14'},
#       {'rank': 7,
#        'name': 'Benjamin Ye',
#        'username': 'glassbricks',
#        'length': 4293,
#        'date': '2022-02-10 04:35:11'},
#       {'rank': 8,
#        'name': 'Jonathan Soo',
#        'username': 'jonathan-soo',
#        'length': 8612,
#        'date': '2020-01-26 08:46:59'}],
#      'description': 'The 10 shortest solutions in Kotlin'}},
#    'OCaml': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Lin Lee',
#        'username': 'lin-lee',
#        'runtime': 0.01,
#        'date': '2019-12-14 10:46:31'},
#       {'rank': 2,
#        'name': 'Shize Li',
#        'username': 'shize-li',
#        'runtime': 0.07,
#        'date': '2023-03-17 01:15:08'},
#       {'rank': 3,
#        'name': 'Ludovic Mignot',
#        'username': 'ludovic-mignot',
#        'runtime': 0.18,
#        'date': '2020-07-12 11:06:44'}],
#      'description': 'The 10 fastest solutions in OCaml'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Lin Lee',
#        'username': 'lin-lee',
#        'length': 683,
#        'date': '2019-12-14 10:46:31'},
#       {'rank': 2,
#        'name': 'Ludovic Mignot',
#        'username': 'ludovic-mignot',
#        'length': 734,
#        'date': '2020-07-12 11:16:58'},
#       {'rank': 3,
#        'name': 'Shize Li',
#        'username': 'shize-li',
#        'length': 936,
#        'date': '2023-03-17 01:15:08'}],
#      'description': 'The 10 shortest solutions in OCaml'}},
#    'PHP': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Valentin Gerbey',
#        'username': 'valentin-gerbey',
#        'runtime': 0.18,
#        'date': '2017-08-28 22:55:24'},
#       {'rank': 2,
#        'name': '姚锦铭',
#        'username': 'kykd4o22',
#        'runtime': 0.95,
#        'date': '2016-11-21 19:11:34'}],
#      'description': 'The 10 fastest solutions in PHP'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': '姚锦铭',
#        'username': 'kykd4o22',
#        'length': 1017,
#        'date': '2016-11-21 19:11:34'},
#       {'rank': 2,
#        'name': 'Valentin Gerbey',
#        'username': 'valentin-gerbey',
#        'length': 1744,
#        'date': '2017-08-28 22:57:07'}],
#      'description': 'The 10 shortest solutions in PHP'}},
#    'Python 3': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Nathan Hu',
#        'username': 'nathan-hu1',
#        'runtime': 0.05,
#        'date': '2024-09-06 04:59:32'},
#       {'rank': 2,
#        'name': 'Perry Weller (student)',
#        'username': 'perry-weller--student-',
#        'runtime': 0.05,
#        'date': '2024-09-11 05:03:49'},
#       {'rank': 3,
#        'name': 'Apraajita Sharma',
#        'username': 'apraajita-sharma',
#        'runtime': 0.05,
#        'date': '2024-09-29 01:12:09'},
#       {'rank': 4,
#        'name': 'Hrithick Chakraborty',
#        'username': 'hrithick-chakraborty',
#        'runtime': 0.05,
#        'date': '2024-10-02 00:20:45'},
#       {'rank': 5,
#        'name': 'Oliver Howe',
#        'username': 'ohowe',
#        'runtime': 0.05,
#        'date': '2024-10-16 06:51:23'},
#       {'rank': 6,
#        'name': 'Andrew Robbins',
#        'username': 'andrew-robbins',
#        'runtime': 0.05,
#        'date': '2024-10-30 16:17:14'},
#       {'rank': 7,
#        'name': 'Donovan Lim',
#        'username': 'donovan-lim1',
#        'runtime': 0.05,
#        'date': '2024-11-07 18:29:57'},
#       {'rank': 8,
#        'name': 'DaiwiK',
#        'username': 'daiwik',
#        'runtime': 0.05,
#        'date': '2024-11-10 22:32:06'},
#       {'rank': 9,
#        'name': 'Wouter Dijkstra',
#        'username': 'wd',
#        'runtime': 0.06,
#        'date': '2022-06-25 18:13:54'},
#       {'rank': 10,
#        'name': 'Alexander Berntsson',
#        'username': 'alexander-berntsson',
#        'runtime': 0.06,
#        'date': '2022-06-27 13:56:22'}],
#      'description': 'The 10 fastest solutions in Python 3'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Loke Gustafsson',
#        'username': 'esnuid',
#        'length': 97,
#        'date': '2024-02-13 22:08:03'},
#       {'rank': 2,
#        'name': 'Nicholas Russell Saerang',
#        'username': 'russellsaerang27',
#        'length': 108,
#        'date': '2023-07-09 10:31:20'},
#       {'rank': 3,
#        'name': 'ANDRES FELIPE GARCIA SANCHEZ',
#        'username': 'andres-felipe-garcia-sanchez',
#        'length': 108,
#        'date': '2024-03-16 16:23:04'},
#       {'rank': 4,
#        'name': 'suka isnaini',
#        'username': 'kenzanin',
#        'length': 108,
#        'date': '2024-05-19 10:30:19'},
#       {'rank': 5,
#        'name': 'Zihong Gong',
#        'username': 'zihong-gong',
#        'length': 110,
#        'date': '2024-10-18 08:52:50'},
#       {'rank': 6,
#        'name': 'HongYuan',
#        'username': 'xiaohu',
#        'length': 110,
#        'date': '2023-09-01 11:28:52'},
#       {'rank': 7,
#        'name': 'MOH JUN ZHOU',
#        'username': 'moh-jun-zhou',
#        'length': 110,
#        'date': '2023-09-22 16:53:33'},
#       {'rank': 8,
#        'name': 'Denis Kevine Simost Sima Matha',
#        'username': 'denis-kevine-simost-sima-matha',
#        'length': 110,
#        'date': '2023-10-29 19:20:41'},
#       {'rank': 9,
#        'name': 'Claudia Porto',
#        'username': 'claudia-porto',
#        'length': 110,
#        'date': '2023-11-17 23:49:38'},
#       {'rank': 10,
#        'name': 'Dante Romero Nava',
#        'username': 'dante-romero-nava',
#        'length': 110,
#        'date': '2024-01-22 16:28:33'}],
#      'description': 'The 10 shortest solutions in Python 3'}},
#    'Ruby': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Thomas Feld',
#        'username': 'tfeld00',
#        'runtime': 0.08,
#        'date': '2024-01-30 14:18:57'},
#       {'rank': 2,
#        'name': 'Hidden user',
#        'username': None,
#        'runtime': 0.23,
#        'date': '2022-12-10 05:36:13'}],
#      'description': 'The 10 fastest solutions in Ruby'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Thomas Feld',
#        'username': 'tfeld00',
#        'length': 81,
#        'date': '2024-01-30 14:50:55'},
#       {'rank': 2,
#        'name': 'Hidden user',
#        'username': None,
#        'length': 137,
#        'date': '2022-12-10 05:36:13'}],
#      'description': 'The 10 shortest solutions in Ruby'}},
#    'Rust': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Benjamin Valpey',
#        'username': 'benjamin-valpey',
#        'runtime': 0.0,
#        'date': '2023-05-19 19:32:01'},
#       {'rank': 2,
#        'name': 'Rio',
#        'username': 'sxu9zooj',
#        'runtime': 0.0,
#        'date': '2023-08-19 13:43:31'},
#       {'rank': 3,
#        'name': 'Hidden user',
#        'username': None,
#        'runtime': 0.01,
#        'date': '2018-11-07 12:31:36'},
#       {'rank': 4,
#        'name': '花井一輝',
#        'username': 'ktrg9zrk',
#        'runtime': 0.01,
#        'date': '2018-11-20 10:29:41'},
#       {'rank': 5,
#        'name': 'Mathias Adam Møller',
#        'username': 'mathias-adam-moller',
#        'runtime': 0.01,
#        'date': '2019-06-24 21:41:51'},
#       {'rank': 6,
#        'name': 'Erik Funder Carstensen',
#        'username': 'erik-funder-carstensen',
#        'runtime': 0.01,
#        'date': '2019-06-24 22:25:26'},
#       {'rank': 7,
#        'name': 'Christofer Nolander',
#        'username': 'christofer-nolander1',
#        'runtime': 0.01,
#        'date': '2019-07-08 16:59:51'},
#       {'rank': 8,
#        'name': 'Lin Lee',
#        'username': 'lin-lee',
#        'runtime': 0.01,
#        'date': '2019-08-10 04:28:49'},
#       {'rank': 9,
#        'name': 'Mathias Svensson',
#        'username': 'mathias-svensson-5716',
#        'runtime': 0.01,
#        'date': '2020-04-08 13:57:15'},
#       {'rank': 10,
#        'name': 'Borja Juan Marin',
#        'username': 'borja-juan-marin',
#        'runtime': 0.01,
#        'date': '2020-05-01 18:11:58'}],
#      'description': 'The 10 fastest solutions in Rust'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Mårten Nilsson',
#        'username': 'marten-nilsson1',
#        'length': 670,
#        'date': '2021-03-22 16:31:50'},
#       {'rank': 2,
#        'name': 'George Kuzler',
#        'username': 'george-kuzler',
#        'length': 697,
#        'date': '2020-12-19 17:56:52'},
#       {'rank': 3,
#        'name': 'Rio',
#        'username': 'sxu9zooj',
#        'length': 736,
#        'date': '2023-08-19 13:52:16'},
#       {'rank': 4,
#        'name': 'Petr Sabel',
#        'username': 'petr-sabel1',
#        'length': 741,
#        'date': '2023-09-29 06:10:15'},
#       {'rank': 5,
#        'name': 'Stevenald Buscemiton',
#        'username': 'stevenald-buscemiton',
#        'length': 760,
#        'date': '2024-09-01 05:06:17'},
#       {'rank': 6,
#        'name': 'Philip Stanton',
#        'username': 'philip-stanton',
#        'length': 817,
#        'date': '2023-02-22 23:38:19'},
#       {'rank': 7,
#        'name': 'Ishtiaq Naqi',
#        'username': 'ihnaqi',
#        'length': 840,
#        'date': '2023-08-10 23:03:26'},
#       {'rank': 8,
#        'name': 'Lin Lee',
#        'username': 'lin-lee',
#        'length': 859,
#        'date': '2019-08-10 04:28:49'},
#       {'rank': 9,
#        'name': 'Julian Beaumont',
#        'username': 'julian-beaumont',
#        'length': 876,
#        'date': '2020-05-27 19:42:41'},
#       {'rank': 10,
#        'name': 'Mathias Adam Møller',
#        'username': 'mathias-adam-moller',
#        'length': 884,
#        'date': '2019-06-24 21:41:51'}],
#      'description': 'The 10 shortest solutions in Rust'}},
#    'TypeScript': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Reuben',
#        'username': 'reuben.g',
#        'runtime': 0.11,
#        'date': '2023-07-17 19:11:13'}],
#      'description': 'The 10 fastest solutions in TypeScript'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Reuben',
#        'username': 'reuben.g',
#        'length': 636,
#        'date': '2023-07-17 19:11:13'}],
#      'description': 'The 10 shortest solutions in TypeScript'}},
#    'Zig': {'fastest': {'ranklist': [{'rank': 1,
#        'name': 'Brage Wiseth',
#        'username': 'bragewiseth',
#        'runtime': 0.01,
#        'date': '2024-05-05 13:46:51'}],
#      'description': 'The 10 fastest solutions in Zig'},
#     'shortest': {'ranklist': [{'rank': 1,
#        'name': 'Brage Wiseth',
#        'username': 'bragewiseth',
#        'length': 875,
#        'date': '2024-05-05 13:46:51'}],
#      'description': 'The 10 shortest solutions in Zig'}}},
#   'submissions': [{'status': 'Wrong Answer',
#     'runtime': '0.04 s',
#     'language': 'Python 3',
#     'test_case_passed': 0,
#     'test_case_full': 41,
#     'link': 'https://open.kattis.com/submissions/14924846'},
#    {'status': 'Run-Time Error',
#     'runtime': '0.06 s',
#     'language': 'Python 3',
#     'test_case_passed': 0,
#     'test_case_full': 41,
#     'link': 'https://open.kattis.com/submissions/14924839'},
#    {'status': 'Compile Error',
#     'runtime': None,
#     'language': 'Python 3',
#     'test_case_passed': None,
#     'test_case_full': None,
#     'link': 'https://open.kattis.com/submissions/14924836'},
#    {'status': 'Accepted',
#     'runtime': '0.10 s',
#     'language': 'Python 3',
#     'test_case_passed': 41,
#     'test_case_full': 41,
#     'link': 'https://open.kattis.com/submissions/11541472'},
#    {'status': 'Accepted',
#     'runtime': '0.10 s',
#     'language': 'Python 3',
#     'test_case_passed': 41,
#     'test_case_full': 41,
#     'link': 'https://open.kattis.com/submissions/11160501'},
#    {'status': 'Run-Time Error',
#     'runtime': '0.05 s',
#     'language': 'Python 3',
#     'test_case_passed': 0,
#     'test_case_full': 41,
#     'link': 'https://open.kattis.com/submissions/10760250'}]}]

# %%
#kt.problems()                               # problems you have solved so far
#kt.problems(show_partial=False)             # exclude partial submissions
kt.problems(low_detail_mode=False)          # include more data for each problem
# Out:
# [{'name': '3D Printed Statues',
#   'id': '3dprinter',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 28621,
#   'acc': 10853,
#   'difficulty': 2.8,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/3dprinter'},
#  {'name': '4 thought',
#   'id': '4thought',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 19397,
#   'acc': 6109,
#   'difficulty': 3.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/4thought'},
#  {'name': '99 Problems',
#   'id': '99problems',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 17757,
#   'acc': 4730,
#   'difficulty': 2.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/99problems'},
#  {'name': 'A1 Paper',
#   'id': 'a1paper',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9470,
#   'acc': 2734,
#   'difficulty': 4.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/a1paper'},
#  {'name': 'Aaah!',
#   'id': 'aaah',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 54628,
#   'acc': 23815,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/aaah'},
#  {'name': 'ABC',
#   'id': 'abc',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 36129,
#   'acc': 14874,
#   'difficulty': 2.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/abc'},
#  {'name': 'Access Denied',
#   'id': 'accessdenied',
#   'fastest': 0.0,
#   'shortest': 155,
#   'total': 2315,
#   'acc': 607,
#   'difficulty': 4.0,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/accessdenied'},
#  {'name': 'Adding Trouble',
#   'id': 'addingtrouble',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 12707,
#   'acc': 6211,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/addingtrouble'},
#  {'name': 'Adding Words',
#   'id': 'addingwords',
#   'fastest': 0.0,
#   'shortest': 192,
#   'total': 22450,
#   'acc': 5405,
#   'difficulty': 4.0,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/addingwords'},
#  {'name': 'Add Two Numbers',
#   'id': 'addtwonumbers',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 35496,
#   'acc': 19300,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/addtwonumbers'},
#  {'name': 'Air Conditioned Minions',
#   'id': 'airconditioned',
#   'fastest': 0.0,
#   'shortest': 127,
#   'total': 11559,
#   'acc': 3340,
#   'difficulty': 3.3,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/airconditioned'},
#  {'name': 'Airfare Grants',
#   'id': 'airfaregrants',
#   'fastest': 0.0,
#   'shortest': 52,
#   'total': 597,
#   'acc': 352,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/airfaregrants'},
#  {'name': 'Á leið í bíó',
#   'id': 'aleidibio',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10239,
#   'acc': 5639,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/aleidibio'},
#  {'name': 'Alice in the Digital World',
#   'id': 'alicedigital',
#   'fastest': 0.01,
#   'shortest': 129,
#   'total': 7496,
#   'acc': 1845,
#   'difficulty': 4.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/alicedigital'},
#  {'name': 'Alien Numbers',
#   'id': 'aliennumbers',
#   'fastest': 0.0,
#   'shortest': 125,
#   'total': 5582,
#   'acc': 2738,
#   'difficulty': 2.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/aliennumbers'},
#  {'name': 'All Different Directions',
#   'id': 'alldifferentdirections',
#   'fastest': 0.0,
#   'shortest': 197,
#   'total': 2611,
#   'acc': 1201,
#   'difficulty': 2.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/alldifferentdirections'},
#  {'name': 'Alloys',
#   'id': 'alloys',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2754,
#   'acc': 826,
#   'difficulty': 3.6,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/alloys'},
#  {'name': 'Alphabet Spam',
#   'id': 'alphabetspam',
#   'fastest': 0.0,
#   'shortest': 66,
#   'total': 16618,
#   'acc': 9697,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/alphabetspam'},
#  {'name': 'Amerískur vinnustaður',
#   'id': 'ameriskur',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8679,
#   'acc': 4220,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ameriskur'},
#  {'name': 'A Multiplication Game',
#   'id': 'amultiplicationgame',
#   'fastest': 0.0,
#   'shortest': 67,
#   'total': 3177,
#   'acc': 1119,
#   'difficulty': 4.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/amultiplicationgame'},
#  {'name': 'A New Alphabet',
#   'id': 'anewalphabet',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 23893,
#   'acc': 9157,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/anewalphabet'},
#  {'name': 'Another Candies',
#   'id': 'anothercandies',
#   'fastest': 0.0,
#   'shortest': 74,
#   'total': 14193,
#   'acc': 3966,
#   'difficulty': 2.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/anothercandies'},
#  {'name': 'Apaxiaaaaaaaaaaaans!',
#   'id': 'apaxiaaans',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 28204,
#   'acc': 16027,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/apaxiaaans'},
#  {'name': 'A Prize No One Can Win',
#   'id': 'aprizenoonecanwin',
#   'fastest': 0.0,
#   'shortest': 71,
#   'total': 8678,
#   'acc': 2659,
#   'difficulty': 3.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/aprizenoonecanwin'},
#  {'name': 'A Real Challenge',
#   'id': 'areal',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 21655,
#   'acc': 8916,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/areal'},
#  {'name': 'Arithmetic',
#   'id': 'arithmetic',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5902,
#   'acc': 1747,
#   'difficulty': 3.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/arithmetic'},
#  {'name': 'ASCII kassi',
#   'id': 'asciikassi',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3448,
#   'acc': 1777,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/asciikassi'},
#  {'name': 'Attendance',
#   'id': 'attendance2',
#   'fastest': 0.0,
#   'shortest': 61,
#   'total': 1252,
#   'acc': 512,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/attendance2'},
#  {'name': 'Autori',
#   'id': 'autori',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 56956,
#   'acc': 31326,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/autori'},
#  {'name': 'Average Character',
#   'id': 'averagecharacter',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4198,
#   'acc': 1730,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/averagecharacter'},
#  {'name': 'Avion',
#   'id': 'avion',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9605,
#   'acc': 5230,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/avion'},
#  {'name': 'Ball',
#   'id': 'ball',
#   'fastest': 0.0,
#   'shortest': 58,
#   'total': 783,
#   'acc': 359,
#   'difficulty': 4.0,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/ball'},
#  {'name': 'Ball Bearings',
#   'id': 'ballbearings',
#   'fastest': 0.0,
#   'shortest': 55,
#   'total': 1098,
#   'acc': 384,
#   'difficulty': 4.1,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/ballbearings'},
#  {'name': 'Bannorð',
#   'id': 'bannord',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1643,
#   'acc': 1045,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bannord'},
#  {'name': 'Barcelona',
#   'id': 'barcelona',
#   'fastest': 0.0,
#   'shortest': 69,
#   'total': 3899,
#   'acc': 1578,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/barcelona'},
#  {'name': 'Basketball One-on-One',
#   'id': 'basketballoneonone',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 26269,
#   'acc': 11303,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/basketballoneonone'},
#  {'name': 'Batter Up',
#   'id': 'batterup',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 17654,
#   'acc': 10768,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/batterup'},
#  {'name': 'Bela',
#   'id': 'bela',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 13971,
#   'acc': 8841,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bela'},
#  {'name': 'BergMál',
#   'id': 'bergmal',
#   'fastest': 0.0,
#   'shortest': 2,
#   'total': 4365,
#   'acc': 2676,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bergmal'},
#  {'name': 'Besta gjöfin',
#   'id': 'bestagjofin',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4137,
#   'acc': 1919,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bestagjofin'},
#  {'name': 'Betting',
#   'id': 'betting',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8674,
#   'acc': 5378,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/betting'},
#  {'name': 'Bijele',
#   'id': 'bijele',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 35493,
#   'acc': 20519,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bijele'},
#  {'name': 'Bishops',
#   'id': 'bishops',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5757,
#   'acc': 2187,
#   'difficulty': 2.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bishops'},
#  {'name': 'Blaðra',
#   'id': 'bladra2',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5755,
#   'acc': 2356,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bladra2'},
#  {'name': 'Blandað Best',
#   'id': 'blandadbest',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3711,
#   'acc': 1894,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/blandadbest'},
#  {'name': 'Blueberry Waffle',
#   'id': 'blueberrywaffle',
#   'fastest': 0.0,
#   'shortest': 54,
#   'total': 2365,
#   'acc': 957,
#   'difficulty': 2.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/blueberrywaffle'},
#  {'name': 'Accounting',
#   'id': 'bokforing',
#   'fastest': 0.01,
#   'shortest': 66,
#   'total': 9006,
#   'acc': 2436,
#   'difficulty': 3.8,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/bokforing'},
#  {'name': 'Boss Battle',
#   'id': 'bossbattle',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9130,
#   'acc': 4775,
#   'difficulty': 2.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bossbattle'},
#  {'name': 'Bracket Matching',
#   'id': 'bracketmatching',
#   'fastest': 0.0,
#   'shortest': 74,
#   'total': 4089,
#   'acc': 1440,
#   'difficulty': 2.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bracketmatching'},
#  {'name': 'Breaking Branches',
#   'id': 'breakingbranches',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1691,
#   'acc': 1197,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/breakingbranches'},
#  {'name': 'Buka',
#   'id': 'buka',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3117,
#   'acc': 1420,
#   'difficulty': 2.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/buka'},
#  {'name': 'Bus',
#   'id': 'bus',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 6197,
#   'acc': 3387,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/bus'},
#  {'name': 'Canadians, eh?',
#   'id': 'canadianseh',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4045,
#   'acc': 1696,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/canadianseh'},
#  {'name': 'Solving for Carrots',
#   'id': 'carrots',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 58040,
#   'acc': 35409,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/carrots'},
#  {'name': 'A Feast For Cats',
#   'id': 'cats',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7214,
#   'acc': 2266,
#   'difficulty': 3.6,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/cats'},
#  {'name': 'Cetvrta',
#   'id': 'cetvrta',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 16346,
#   'acc': 10084,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cetvrta'},
#  {'name': 'Chanukah Challenge',
#   'id': 'chanukah',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 12802,
#   'acc': 7412,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/chanukah'},
#  {'name': 'Character Development',
#   'id': 'character',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3766,
#   'acc': 1764,
#   'difficulty': 2.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/character'},
#  {'name': 'Class Field Trip',
#   'id': 'classfieldtrip',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4877,
#   'acc': 3097,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/classfieldtrip'},
#  {'name': 'A Classy Problem',
#   'id': 'classy',
#   'fastest': 0.01,
#   'shortest': 130,
#   'total': 19896,
#   'acc': 4924,
#   'difficulty': 4.8,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/classy'},
#  {'name': 'Cold-puter Science',
#   'id': 'cold',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 51155,
#   'acc': 30230,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cold'},
#  {'name': 'Combinatorial Stanley Cup',
#   'id': 'combinatorialstanleycup',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 561,
#   'acc': 309,
#   'difficulty': 3.0,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/combinatorialstanleycup'},
#  {'name': 'Common Factors',
#   'id': 'commonfactors',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1417,
#   'acc': 479,
#   'difficulty': 4.6,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/commonfactors'},
#  {'name': 'Jumbled Compass',
#   'id': 'compass',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8089,
#   'acc': 3406,
#   'difficulty': 2.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/compass'},
#  {'name': 'Competitive Arcade Basketball',
#   'id': 'competitivearcadebasketball',
#   'fastest': 0.02,
#   'shortest': 86,
#   'total': 3309,
#   'acc': 1360,
#   'difficulty': 2.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/competitivearcadebasketball'},
#  {'name': 'Conformity',
#   'id': 'conformity',
#   'fastest': 0.0,
#   'shortest': 62,
#   'total': 12747,
#   'acc': 5816,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/conformity'},
#  {'name': 'Conquest Campaign',
#   'id': 'conquestcampaign',
#   'fastest': 0.0,
#   'shortest': 176,
#   'total': 2680,
#   'acc': 1086,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/conquestcampaign'},
#  {'name': "Cryptographer's Conundrum",
#   'id': 'conundrum',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 15352,
#   'acc': 9279,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/conundrum'},
#  {'name': 'Cosmic Path Optimization',
#   'id': 'cosmicpathoptimization',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2321,
#   'acc': 1411,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cosmicpathoptimization'},
#  {'name': 'Costume Contest',
#   'id': 'costumecontest',
#   'fastest': 0.0,
#   'shortest': 56,
#   'total': 2604,
#   'acc': 1335,
#   'difficulty': 2.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/costumecontest'},
#  {'name': 'Count the Vowels',
#   'id': 'countthevowels',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 12383,
#   'acc': 6384,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/countthevowels'},
#  {'name': 'CPR Number',
#   'id': 'cprnummer',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4035,
#   'acc': 2423,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cprnummer'},
#  {'name': 'Crne',
#   'id': 'crne',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3289,
#   'acc': 1297,
#   'difficulty': 2.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/crne'},
#  {'name': 'Cudoviste',
#   'id': 'cudoviste',
#   'fastest': 0.0,
#   'shortest': 75,
#   'total': 4828,
#   'acc': 3408,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cudoviste'},
#  {'name': 'Stacking Cups',
#   'id': 'cups',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9598,
#   'acc': 5563,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cups'},
#  {'name': 'Cut the Negativity',
#   'id': 'cutthenegativity',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3203,
#   'acc': 1721,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cutthenegativity'},
#  {'name': 'Cyanide Rivers',
#   'id': 'cyaniderivers',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 687,
#   'acc': 342,
#   'difficulty': 2.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/cyaniderivers'},
#  {'name': 'Dagatal',
#   'id': 'dagatal',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2807,
#   'acc': 1273,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/dagatal'},
#  {'name': 'Damaged Equation',
#   'id': 'damagedequation',
#   'fastest': 0.0,
#   'shortest': 135,
#   'total': 1488,
#   'acc': 504,
#   'difficulty': 2.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/damagedequation'},
#  {'name': 'Datum',
#   'id': 'datum',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9778,
#   'acc': 5738,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/datum'},
#  {'name': 'Death Knight Hero',
#   'id': 'deathknight',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7649,
#   'acc': 3936,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/deathknight'},
#  {'name': 'Deathstar',
#   'id': 'deathstar',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2465,
#   'acc': 1759,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/deathstar'},
#  {'name': 'Decimal deletion',
#   'id': 'decimaldeletion',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2315,
#   'acc': 1144,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/decimaldeletion'},
#  {'name': 'Detailed Differences',
#   'id': 'detaileddifferences',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 22413,
#   'acc': 11217,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/detaileddifferences'},
#  {'name': 'Dice Cup',
#   'id': 'dicecup',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 19298,
#   'acc': 12156,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/dicecup'},
#  {'name': 'A Different Problem',
#   'id': 'different',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 67405,
#   'acc': 22466,
#   'difficulty': 2.8,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/different'},
#  {'name': 'Digit Swap',
#   'id': 'digitswap',
#   'fastest': 0.0,
#   'shortest': 2,
#   'total': 19559,
#   'acc': 11631,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/digitswap'},
#  {'name': 'Disc District',
#   'id': 'discdistrict',
#   'fastest': 0.0,
#   'shortest': 2,
#   'total': 2320,
#   'acc': 1154,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/discdistrict'},
#  {'name': 'Distributing Poffins',
#   'id': 'distributingpoffins',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 597,
#   'acc': 380,
#   'difficulty': 2.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/distributingpoffins'},
#  {'name': 'Draga Frá',
#   'id': 'dragafra',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 6679,
#   'acc': 4069,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/dragafra'},
#  {'name': 'DRM Messages',
#   'id': 'drmmessages',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5979,
#   'acc': 3893,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/drmmessages'},
#  {'name': 'The Easiest Problem Is This One',
#   'id': 'easiest',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 12929,
#   'acc': 7075,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/easiest'},
#  {'name': 'Echo Echo Echo',
#   'id': 'echoechoecho',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 35096,
#   'acc': 19265,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/echoechoecho'},
#  {'name': 'Ekki dauði opna inni',
#   'id': 'ekkidaudi',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2859,
#   'acc': 1600,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ekkidaudi'},
#  {'name': 'Election',
#   'id': 'election2',
#   'fastest': 0.0,
#   'shortest': 112,
#   'total': 1827,
#   'acc': 711,
#   'difficulty': 2.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/election2'},
#  {'name': 'Electrical Outlets',
#   'id': 'electricaloutlets',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10423,
#   'acc': 6507,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/electricaloutlets'},
#  {'name': 'Encoded Message',
#   'id': 'encodedmessage',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8200,
#   'acc': 5228,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/encodedmessage'},
#  {'name': 'Estimating the Area of a Circle',
#   'id': 'estimatingtheareaofacircle',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7990,
#   'acc': 4467,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/estimatingtheareaofacircle'},
#  {'name': "I've Been Everywhere, Man",
#   'id': 'everywhere',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 25979,
#   'acc': 15864,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/everywhere'},
#  {'name': 'Eye of Sauron',
#   'id': 'eyeofsauron',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9327,
#   'acc': 5111,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/eyeofsauron'},
#  {'name': 'Fading Wind',
#   'id': 'fadingwind',
#   'fastest': 0.0,
#   'shortest': 99,
#   'total': 2137,
#   'acc': 1099,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/fadingwind'},
#  {'name': 'Faktor',
#   'id': 'faktor',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 26995,
#   'acc': 17560,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/faktor'},
#  {'name': 'Framtíðar FIFA',
#   'id': 'fifa',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 11581,
#   'acc': 6011,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/fifa'},
#  {'name': 'Fifty Shades of Pink',
#   'id': 'fiftyshades',
#   'fastest': 0.0,
#   'shortest': 70,
#   'total': 6478,
#   'acc': 3537,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/fiftyshades'},
#  {'name': 'Filip',
#   'id': 'filip',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 28079,
#   'acc': 16475,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/filip'},
#  {'name': 'Final Exam',
#   'id': 'finalexam2',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5061,
#   'acc': 3041,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/finalexam2'},
#  {'name': 'Finding An A',
#   'id': 'findingana',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 16539,
#   'acc': 9269,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/findingana'},
#  {'name': 'FizzBuzz',
#   'id': 'fizzbuzz',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 49322,
#   'acc': 25970,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/fizzbuzz'},
#  {'name': 'Flatbökuveisla',
#   'id': 'flatbokuveisla',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8767,
#   'acc': 5000,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/flatbokuveisla'},
#  {'name': 'Flýtibaka',
#   'id': 'flytibaka',
#   'fastest': 0.0,
#   'shortest': 0,
#   'total': 3215,
#   'acc': 1768,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/flytibaka'},
#  {'name': 'Forced Choice',
#   'id': 'forcedchoice',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2899,
#   'acc': 1895,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/forcedchoice'},
#  {'name': 'Free Food',
#   'id': 'freefood',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9608,
#   'acc': 5974,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/freefood'},
#  {'name': 'FYI',
#   'id': 'fyi',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 19868,
#   'acc': 10430,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/fyi'},
#  {'name': 'Gangur',
#   'id': 'gangur',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2690,
#   'acc': 1945,
#   'difficulty': 2.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/gangur'},
#  {'name': 'GCD',
#   'id': 'gcd',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3862,
#   'acc': 1977,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/gcd'},
#  {'name': 'GCVWR',
#   'id': 'gcvwr',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 6692,
#   'acc': 3765,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/gcvwr'},
#  {'name': 'Ghost Leg',
#   'id': 'ghostleg',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2370,
#   'acc': 1600,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ghostleg'},
#  {'name': "Glasses Foggy, Mom's Spaghetti",
#   'id': 'glassesfoggymomsspaghetti',
#   'fastest': 0.0,
#   'shortest': 77,
#   'total': 360,
#   'acc': 206,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/glassesfoggymomsspaghetti'},
#  {'name': 'Grading',
#   'id': 'grading',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5571,
#   'acc': 2972,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/grading'},
#  {'name': 'Grass Seed Inc.',
#   'id': 'grassseed',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 20036,
#   'acc': 11185,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/grassseed'},
#  {'name': 'Greetings!',
#   'id': 'greetings2',
#   'fastest': 0.0,
#   'shortest': 2,
#   'total': 20652,
#   'acc': 12011,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/greetings2'},
#  {'name': 'Harshad Numbers',
#   'id': 'harshadnumbers',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9739,
#   'acc': 5909,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/harshadnumbers'},
#  {'name': 'Haughty Cuisine',
#   'id': 'haughtycuisine',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1246,
#   'acc': 734,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/haughtycuisine'},
#  {'name': 'Heart Rate',
#   'id': 'heartrate',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 12323,
#   'acc': 7896,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/heartrate'},
#  {'name': 'Heimavinna',
#   'id': 'heimavinna',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 11380,
#   'acc': 7587,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/heimavinna'},
#  {'name': 'Hello World!',
#   'id': 'hello',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 246260,
#   'acc': 129215,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/hello'},
#  {'name': 'Herman',
#   'id': 'herman',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8953,
#   'acc': 4284,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/herman'},
#  {'name': 'Hipp Hipp',
#   'id': 'hipphipp',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 18322,
#   'acc': 8623,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/hipphipp'},
#  {'name': 'Hipp Hipp Húrra',
#   'id': 'hipphipphurra',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5057,
#   'acc': 2334,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/hipphipphurra'},
#  {'name': 'Hissing Microphone',
#   'id': 'hissingmicrophone',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 34959,
#   'acc': 18622,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/hissingmicrophone'},
#  {'name': 'Howl',
#   'id': 'howl',
#   'fastest': 0.0,
#   'shortest': 2,
#   'total': 6115,
#   'acc': 2700,
#   'difficulty': 2.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/howl'},
#  {'name': 'Hraðgreining',
#   'id': 'hradgreining',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9338,
#   'acc': 5071,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/hradgreining'},
#  {'name': 'The Amazing Human Cannonball',
#   'id': 'humancannonball2',
#   'fastest': 0.0,
#   'shortest': 140,
#   'total': 7489,
#   'acc': 4520,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/humancannonball2'},
#  {'name': 'ICPC Awards',
#   'id': 'icpcawards',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7813,
#   'acc': 4561,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/icpcawards'},
#  {'name': 'International Dates',
#   'id': 'internationaldates',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2554,
#   'acc': 1427,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/internationaldates'},
#  {'name': 'IsItHalloween.com',
#   'id': 'isithalloween',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 23763,
#   'acc': 12046,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/isithalloween'},
#  {'name': 'Is Y a Vowel?',
#   'id': 'isyavowel',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5910,
#   'acc': 3143,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/isyavowel'},
#  {'name': "Jack-O'-Lantern Juxtaposition",
#   'id': 'jackolanternjuxtaposition',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 25514,
#   'acc': 14824,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/jackolanternjuxtaposition'},
#  {'name': 'Janitor Troubles',
#   'id': 'janitortroubles',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4361,
#   'acc': 2901,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/janitortroubles'},
#  {'name': 'Job Expenses',
#   'id': 'jobexpenses',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 12664,
#   'acc': 6638,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/jobexpenses'},
#  {'name': 'Joint Jog Jam',
#   'id': 'jointjogjam',
#   'fastest': 0.0,
#   'shortest': 56,
#   'total': 1852,
#   'acc': 1191,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/jointjogjam'},
#  {'name': 'Judging Moose',
#   'id': 'judgingmoose',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 23032,
#   'acc': 10424,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/judgingmoose'},
#  {'name': 'Jumbo Javelin',
#   'id': 'jumbojavelin',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 17908,
#   'acc': 10177,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/jumbojavelin'},
#  {'name': 'Karte',
#   'id': 'karte',
#   'fastest': 0.0,
#   'shortest': 88,
#   'total': 5745,
#   'acc': 3216,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/karte'},
#  {'name': 'Kemija',
#   'id': 'kemija08',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8436,
#   'acc': 5170,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/kemija08'},
#  {'name': 'The Key to Cryptography',
#   'id': 'keytocrypto',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4025,
#   'acc': 2237,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/keytocrypto'},
#  {'name': 'Keywords',
#   'id': 'keywords',
#   'fastest': 0.01,
#   'shortest': 5,
#   'total': 4206,
#   'acc': 1768,
#   'difficulty': 1.9,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/keywords'},
#  {'name': 'Kiki Boba',
#   'id': 'kikiboba',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 6759,
#   'acc': 4227,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/kikiboba'},
#  {'name': 'Knapsack',
#   'id': 'knapsack',
#   'fastest': 0.01,
#   'shortest': 338,
#   'total': 19685,
#   'acc': 5100,
#   'difficulty': 4.3,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/knapsack'},
#  {'name': 'Knight Packing',
#   'id': 'knightpacking',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10011,
#   'acc': 6078,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/knightpacking'},
#  {'name': 'Knitpicking',
#   'id': 'knitpicking',
#   'fastest': 0.0,
#   'shortest': 151,
#   'total': 895,
#   'acc': 396,
#   'difficulty': 3.0,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/knitpicking'},
#  {'name': 'Knot Knowledge',
#   'id': 'knotknowledge',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 6681,
#   'acc': 3892,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/knotknowledge'},
#  {'name': 'Kornislav',
#   'id': 'kornislav',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8059,
#   'acc': 5244,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/kornislav'},
#  {'name': 'Kveðja',
#   'id': 'kvedja',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5246,
#   'acc': 3169,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/kvedja'},
#  {'name': 'Ladder',
#   'id': 'ladder',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 20449,
#   'acc': 11284,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ladder'},
#  {'name': 'Lamps',
#   'id': 'lamps',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2696,
#   'acc': 1820,
#   'difficulty': 3.0,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/lamps'},
#  {'name': 'Laptop Sticker',
#   'id': 'laptopsticker',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 6539,
#   'acc': 3619,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/laptopsticker'},
#  {'name': 'Last Factorial Digit',
#   'id': 'lastfactorialdigit',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 26960,
#   'acc': 14840,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/lastfactorialdigit'},
#  {'name': 'Last Minute',
#   'id': 'lastminute',
#   'fastest': 0.0,
#   'shortest': 65,
#   'total': 825,
#   'acc': 366,
#   'difficulty': 2.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/lastminute'},
#  {'name': 'Leggja saman',
#   'id': 'leggjasaman',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 17714,
#   'acc': 8721,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/leggjasaman'},
#  {'name': 'Leyniþjónusta',
#   'id': 'leynithjonusta',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3090,
#   'acc': 2589,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/leynithjonusta'},
#  {'name': 'Longest Prime Sum',
#   'id': 'longestprimesum',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2136,
#   'acc': 808,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/longestprimesum'},
#  {'name': 'Lubbi Lærir',
#   'id': 'lubbilaerir',
#   'fastest': 0.0,
#   'shortest': 2,
#   'total': 5260,
#   'acc': 3610,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/lubbilaerir'},
#  {'name': 'Magic Trick',
#   'id': 'magictrick',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9185,
#   'acc': 5275,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/magictrick'},
#  {'name': 'Making A Meowth',
#   'id': 'makingameowth',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1856,
#   'acc': 1076,
#   'difficulty': 1.9,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/makingameowth'},
#  {'name': 'Mars Window',
#   'id': 'marswindow',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4828,
#   'acc': 1897,
#   'difficulty': 2.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/marswindow'},
#  {'name': 'Maximum Choice',
#   'id': 'maximumchoice',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 441,
#   'acc': 158,
#   'difficulty': 3.8,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/maximumchoice'},
#  {'name': 'Message',
#   'id': 'meddelande',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2870,
#   'acc': 1631,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/meddelande'},
#  {'name': 'Meeting Points',
#   'id': 'meetingpoints',
#   'fastest': 0.01,
#   'shortest': 167,
#   'total': 522,
#   'acc': 112,
#   'difficulty': 5.5,
#   'category': 'Hard',
#   'link': 'https://open.kattis.com/problems/meetingpoints'},
#  {'name': 'Methodic Multiplication',
#   'id': 'methodicmultiplication',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2652,
#   'acc': 1671,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/methodicmultiplication'},
#  {'name': 'Metronome',
#   'id': 'metronome',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 19041,
#   'acc': 10351,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/metronome'},
#  {'name': 'Millifærsla',
#   'id': 'millifaersla',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8476,
#   'acc': 3874,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/millifaersla'},
#  {'name': 'Missing Numbers',
#   'id': 'missingnumbers',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 9982,
#   'acc': 5188,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/missingnumbers'},
#  {'name': 'Modulo',
#   'id': 'modulo',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 21479,
#   'acc': 12623,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/modulo'},
#  {'name': 'Monopoly',
#   'id': 'monopol',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3143,
#   'acc': 1744,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/monopol'},
#  {'name': 'Mult!',
#   'id': 'mult',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3516,
#   'acc': 1961,
#   'difficulty': 2.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/mult'},
#  {'name': 'Nasty Hacks',
#   'id': 'nastyhacks',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 26371,
#   'acc': 14839,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/nastyhacks'},
#  {'name': 'Nikola',
#   'id': 'nikola',
#   'fastest': 0.0,
#   'shortest': 216,
#   'total': 5282,
#   'acc': 1672,
#   'difficulty': 4.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/nikola'},
#  {'name': 'No Duplicates',
#   'id': 'nodup',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 19935,
#   'acc': 10459,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/nodup'},
#  {'name': 'N-sum',
#   'id': 'nsum',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 18808,
#   'acc': 10615,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/nsum'},
#  {'name': 'Number Fun',
#   'id': 'numberfun',
#   'fastest': 0.0,
#   'shortest': 82,
#   'total': 20790,
#   'acc': 10255,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/numberfun'},
#  {'name': "Odd A's, Even B's",
#   'id': 'oddaevenb',
#   'fastest': 0.0,
#   'shortest': 64,
#   'total': 510,
#   'acc': 215,
#   'difficulty': 4.4,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/oddaevenb'},
#  {'name': 'Odd Echo',
#   'id': 'oddecho',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 25836,
#   'acc': 12247,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/oddecho'},
#  {'name': 'Odd Gnome',
#   'id': 'oddgnome',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10227,
#   'acc': 5530,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/oddgnome'},
#  {'name': 'Oddities',
#   'id': 'oddities',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 46506,
#   'acc': 24443,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/oddities'},
#  {'name': 'Odd Man Out',
#   'id': 'oddmanout',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 15967,
#   'acc': 8843,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/oddmanout'},
#  {'name': 'Öfugsnúið',
#   'id': 'ofugsnuid',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 26062,
#   'acc': 16016,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ofugsnuid'},
#  {'name': 'Oktalni',
#   'id': 'oktalni',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2890,
#   'acc': 1543,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/oktalni'},
#  {'name': 'Out of Sorts',
#   'id': 'outofsorts',
#   'fastest': 0.01,
#   'shortest': 5,
#   'total': 3377,
#   'acc': 1392,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/outofsorts'},
#  {'name': 'Over the Hill, Part 1',
#   'id': 'overthehill1',
#   'fastest': 0.0,
#   'shortest': 155,
#   'total': 543,
#   'acc': 291,
#   'difficulty': 2.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/overthehill1'},
#  {'name': 'Óvissa',
#   'id': 'ovissa',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 16362,
#   'acc': 8519,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ovissa'},
#  {'name': 'Paintball',
#   'id': 'paintball',
#   'fastest': 0.0,
#   'shortest': 599,
#   'total': 4363,
#   'acc': 1585,
#   'difficulty': 3.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/paintball'},
#  {'name': 'Parking',
#   'id': 'parking2',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8026,
#   'acc': 5028,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/parking2'},
#  {'name': 'Pea Pattern',
#   'id': 'peapattern',
#   'fastest': 0.0,
#   'shortest': 96,
#   'total': 735,
#   'acc': 215,
#   'difficulty': 4.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/peapattern'},
#  {'name': 'Pet',
#   'id': 'pet',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 28780,
#   'acc': 16338,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pet'},
#  {'name': 'Piece of Cake!',
#   'id': 'pieceofcake2',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 14788,
#   'acc': 8974,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pieceofcake2'},
#  {'name': 'A Vicious Pikeman (Easy)',
#   'id': 'pikemaneasy',
#   'fastest': 0.0,
#   'shortest': 127,
#   'total': 5288,
#   'acc': 1763,
#   'difficulty': 2.9,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/pikemaneasy'},
#  {'name': 'Pizza Crust',
#   'id': 'pizza2',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 14907,
#   'acc': 6530,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pizza2'},
#  {'name': 'Pizzastrengur',
#   'id': 'pizzastrengur',
#   'fastest': 0.01,
#   'shortest': 133,
#   'total': 4419,
#   'acc': 2063,
#   'difficulty': 2.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pizzastrengur'},
#  {'name': 'Pizzubestun',
#   'id': 'pizzubestun',
#   'fastest': 0.01,
#   'shortest': 61,
#   'total': 1451,
#   'acc': 566,
#   'difficulty': 2.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pizzubestun'},
#  {'name': 'Planina',
#   'id': 'planina',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 24076,
#   'acc': 14391,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/planina'},
#  {'name': 'Pokechat',
#   'id': 'pokechat',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3747,
#   'acc': 2183,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pokechat'},
#  {'name': 'Poker Hand',
#   'id': 'pokerhand',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10980,
#   'acc': 6471,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pokerhand'},
#  {'name': 'Popcorn',
#   'id': 'popkorn',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3142,
#   'acc': 1840,
#   'difficulty': 3.1,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/popkorn'},
#  {'name': 'Pot',
#   'id': 'pot',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 34672,
#   'acc': 19663,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pot'},
#  {'name': 'Primality',
#   'id': 'primality',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1955,
#   'acc': 686,
#   'difficulty': 5.4,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/primality'},
#  {'name': 'Prime Count',
#   'id': 'primecount',
#   'fastest': 0.02,
#   'shortest': 461,
#   'total': 1476,
#   'acc': 706,
#   'difficulty': 8.6,
#   'category': 'Hard',
#   'link': 'https://open.kattis.com/problems/primecount'},
#  {'name': 'Prjónamynstur',
#   'id': 'prjonamynstur',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2506,
#   'acc': 1549,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/prjonamynstur'},
#  {'name': 'Provinces and Gold',
#   'id': 'provincesandgold',
#   'fastest': 0.0,
#   'shortest': 109,
#   'total': 9380,
#   'acc': 5153,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/provincesandgold'},
#  {'name': 'Prsteni',
#   'id': 'prsteni',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4189,
#   'acc': 2613,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/prsteni'},
#  {'name': 'Pseudoprime numbers',
#   'id': 'pseudoprime',
#   'fastest': 0.0,
#   'shortest': 91,
#   'total': 2707,
#   'acc': 1048,
#   'difficulty': 3.7,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/pseudoprime'},
#  {'name': 'Ptice',
#   'id': 'ptice',
#   'fastest': 0.0,
#   'shortest': 153,
#   'total': 6805,
#   'acc': 3901,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ptice'},
#  {'name': 'Building Pyramids',
#   'id': 'pyramids',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10268,
#   'acc': 4888,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/pyramids'},
#  {'name': 'Quality-Adjusted Life-Year',
#   'id': 'qaly',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 34978,
#   'acc': 19980,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/qaly'},
#  {'name': 'Quadrant Selection',
#   'id': 'quadrant',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 68375,
#   'acc': 37220,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/quadrant'},
#  {'name': 'Quick Estimates',
#   'id': 'quickestimate',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 15052,
#   'acc': 8147,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/quickestimate'},
#  {'name': 'R2',
#   'id': 'r2',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 69087,
#   'acc': 38632,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/r2'},
#  {'name': 'Racing Around the Alphabet',
#   'id': 'racingalphabet',
#   'fastest': 0.0,
#   'shortest': 126,
#   'total': 3002,
#   'acc': 1832,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/racingalphabet'},
#  {'name': 'Railroad',
#   'id': 'railroad2',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7119,
#   'acc': 4549,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/railroad2'},
#  {'name': 'Rating Problems',
#   'id': 'ratingproblems',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 11151,
#   'acc': 6287,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/ratingproblems'},
# ...
#   'shortest': 5,
#   'total': 1329,
#   'acc': 650,
#   'difficulty': 2.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sanic'},
#  {'name': 'Secure Doors',
#   'id': 'securedoors',
#   'fastest': 0.0,
#   'shortest': 81,
#   'total': 8356,
#   'acc': 4113,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/securedoors'},
#  {'name': '0-1 Sequences',
#   'id': 'sequences',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 19409,
#   'acc': 3061,
#   'difficulty': 5.4,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/sequences'},
#  {'name': 'Seven Wonders',
#   'id': 'sevenwonders',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 17594,
#   'acc': 9391,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sevenwonders'},
#  {'name': 'Shattered Cake',
#   'id': 'shatteredcake',
#   'fastest': 0.01,
#   'shortest': 5,
#   'total': 12510,
#   'acc': 7730,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/shatteredcake'},
#  {'name': 'Shiritori',
#   'id': 'shiritori',
#   'fastest': 0.03,
#   'shortest': 96,
#   'total': 5667,
#   'acc': 2218,
#   'difficulty': 2.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/shiritori'},
#  {'name': 'Shopping List',
#   'id': 'shoppinglist',
#   'fastest': 0.02,
#   'shortest': 51,
#   'total': 3422,
#   'acc': 1244,
#   'difficulty': 2.8,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/shoppinglist'},
#  {'name': 'A Shortcut to What?',
#   'id': 'shortcuttowhat',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3008,
#   'acc': 1723,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/shortcuttowhat'},
#  {'name': 'Shortest Composite Sum',
#   'id': 'shortestcompositesum',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 723,
#   'acc': 270,
#   'difficulty': 4.2,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/shortestcompositesum'},
#  {'name': 'Sibice',
#   'id': 'sibice',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 24408,
#   'acc': 13560,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sibice'},
#  {'name': 'Simon Says',
#   'id': 'simonsays',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 24798,
#   'acc': 12651,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/simonsays'},
#  {'name': 'Simple Addition',
#   'id': 'simpleaddition',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 11181,
#   'acc': 4534,
#   'difficulty': 2.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/simpleaddition'},
#  {'name': 'Sith',
#   'id': 'sith',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2633,
#   'acc': 1251,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sith'},
#  {'name': 'Skák',
#   'id': 'skak',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1736,
#   'acc': 957,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/skak'},
#  {'name': 'Skammstöfun',
#   'id': 'skammstofun',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3076,
#   'acc': 1686,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/skammstofun'},
#  {'name': 'Skener',
#   'id': 'skener',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7404,
#   'acc': 4822,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/skener'},
#  {'name': 'Skocimis',
#   'id': 'skocimis',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8934,
#   'acc': 4938,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/skocimis'},
#  {'name': 'Turn It Up!',
#   'id': 'skruop',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7896,
#   'acc': 4316,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/skruop'},
#  {'name': 'Sky Islands',
#   'id': 'skyislands',
#   'fastest': 0.02,
#   'shortest': 220,
#   'total': 5043,
#   'acc': 1987,
#   'difficulty': 2.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/skyislands'},
#  {'name': 'Slatkisi',
#   'id': 'slatkisi',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1912,
#   'acc': 968,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/slatkisi'},
#  {'name': 'Sly Students',
#   'id': 'slystudents',
#   'fastest': 0.0,
#   'shortest': 76,
#   'total': 232,
#   'acc': 137,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/slystudents'},
#  {'name': 'SMIL',
#   'id': 'smil',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7958,
#   'acc': 4509,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/smil'},
#  {'name': 'Soda Slurper',
#   'id': 'sodaslurper',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10994,
#   'acc': 6201,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sodaslurper'},
#  {'name': 'Sort Two Numbers',
#   'id': 'sorttwonumbers',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 30321,
#   'acc': 14819,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sorttwonumbers'},
#  {'name': 'Sóttkví',
#   'id': 'sottkvi',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 1767,
#   'acc': 956,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sottkvi'},
#  {'name': 'Soylent',
#   'id': 'soylent',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 11348,
#   'acc': 4980,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/soylent'},
#  {'name': 'Spavanac',
#   'id': 'spavanac',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 30566,
#   'acc': 16060,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/spavanac'},
#  {'name': 'Speed Limit',
#   'id': 'speedlimit',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 27035,
#   'acc': 14195,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/speedlimit'},
#  {'name': 'Speedrun',
#   'id': 'speedrun',
#   'fastest': 0.0,
#   'shortest': 87,
#   'total': 1152,
#   'acc': 564,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/speedrun'},
#  {'name': 'Spritt',
#   'id': 'spritt',
#   'fastest': 0.01,
#   'shortest': 5,
#   'total': 6645,
#   'acc': 3107,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/spritt'},
#  {'name': 'Square Peg',
#   'id': 'squarepeg',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2418,
#   'acc': 1299,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/squarepeg'},
#  {'name': 'Sticky Keys',
#   'id': 'stickykeys',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2761,
#   'acc': 1607,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/stickykeys'},
#  {'name': 'Stopwatch',
#   'id': 'stopwatch',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10296,
#   'acc': 5883,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/stopwatch'},
#  {'name': 'Stórafmæli',
#   'id': 'storafmaeli',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 6005,
#   'acc': 3296,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/storafmaeli'},
#  {'name': 'Sum of the Others',
#   'id': 'sumoftheothers',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4615,
#   'acc': 2226,
#   'difficulty': 2.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sumoftheothers'},
#  {'name': 'Sum Squared Digits Function',
#   'id': 'sumsquareddigits',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5842,
#   'acc': 3764,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/sumsquareddigits'},
#  {'name': 'Symmetric Order',
#   'id': 'symmetricorder',
#   'fastest': 0.0,
#   'shortest': 71,
#   'total': 12635,
#   'acc': 7140,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/symmetricorder'},
#  {'name': 'T9 Spelling',
#   'id': 't9spelling',
#   'fastest': 0.0,
#   'shortest': 168,
#   'total': 19904,
#   'acc': 8315,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/t9spelling'},
#  {'name': 'Tabs and spaces',
#   'id': 'tabsandspaces',
#   'fastest': 0.0,
#   'shortest': 114,
#   'total': 458,
#   'acc': 184,
#   'difficulty': 3.4,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/tabsandspaces'},
#  {'name': "Tai's formula",
#   'id': 'taisformula',
#   'fastest': 0.0,
#   'shortest': 62,
#   'total': 4188,
#   'acc': 2356,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/taisformula'},
#  {'name': 'Takkar',
#   'id': 'takkar',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3763,
#   'acc': 2835,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/takkar'},
#  {'name': 'Takk fyrir mig',
#   'id': 'takkfyrirmig',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4410,
#   'acc': 2304,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/takkfyrirmig'},
#  {'name': 'Tarifa',
#   'id': 'tarifa',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 43043,
#   'acc': 24019,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/tarifa'},
#  {'name': 'Temperature Confusion',
#   'id': 'temperatureconfusion',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2907,
#   'acc': 1267,
#   'difficulty': 2.8,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/temperatureconfusion'},
#  {'name': 'Tetration',
#   'id': 'tetration',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3851,
#   'acc': 2257,
#   'difficulty': 1.7,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/tetration'},
#  {'name': 'Thanos',
#   'id': 'thanos',
#   'fastest': 0.0,
#   'shortest': 59,
#   'total': 11520,
#   'acc': 3109,
#   'difficulty': 2.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/thanos'},
#  {'name': 'The Last Problem',
#   'id': 'thelastproblem',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 10501,
#   'acc': 4756,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/thelastproblem'},
#  {'name': 'The Plank',
#   'id': 'theplank',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 3081,
#   'acc': 1891,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/theplank'},
#  {'name': 'Til hamingju',
#   'id': 'tilhamingju',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 8663,
#   'acc': 5801,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/tilhamingju'},
#  {'name': 'Stuck In A Time Loop',
#   'id': 'timeloop',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 90658,
#   'acc': 43561,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/timeloop'},
#  {'name': 'Tölvunarfræðingar telja',
#   'id': 'tolvunarfraedingartelja',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 11106,
#   'acc': 6024,
#   'difficulty': 1.1,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/tolvunarfraedingartelja'},
#  {'name': 'Transit Woes',
#   'id': 'transitwoes',
#   'fastest': 0.0,
#   'shortest': 101,
#   'total': 4907,
#   'acc': 3052,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/transitwoes'},
#  {'name': 'Triangle Area',
#   'id': 'triarea',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 24233,
#   'acc': 12226,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/triarea'},
#  {'name': 'Trik',
#   'id': 'trik',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 27080,
#   'acc': 15324,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/trik'},
#  {'name': 'Take Two Stones',
#   'id': 'twostones',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 76779,
#   'acc': 42086,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/twostones'},
#  {'name': 'Two-sum',
#   'id': 'twosum',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 27206,
#   'acc': 14445,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/twosum'},
#  {'name': 'Umferð',
#   'id': 'umferd',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4464,
#   'acc': 2177,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/umferd'},
#  {'name': 'Undead or Alive',
#   'id': 'undeadoralive',
#   'fastest': 0.0,
#   'shortest': 58,
#   'total': 4756,
#   'acc': 2551,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/undeadoralive'},
#  {'name': 'Arrangement',
#   'id': 'upprodun',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5363,
#   'acc': 3741,
#   'difficulty': 1.6,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/upprodun'},
#  {'name': 'Vaccine Efficacy',
#   'id': 'vaccineefficacy',
#   'fastest': 0.0,
#   'shortest': 150,
#   'total': 3146,
#   'acc': 1191,
#   'difficulty': 3.1,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/vaccineefficacy'},
#  {'name': 'Vauvau',
#   'id': 'vauvau',
#   'fastest': 0.0,
#   'shortest': 79,
#   'total': 3676,
#   'acc': 2094,
#   'difficulty': 2.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/vauvau'},
#  {'name': 'Veður - Lokaðar heiðar',
#   'id': 'vedurheidar',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4285,
#   'acc': 1804,
#   'difficulty': 1.3,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/vedurheidar'},
#  {'name': 'Vefþjónatjón',
#   'id': 'vefthjonatjon',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 2099,
#   'acc': 1042,
#   'difficulty': 1.5,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/vefthjonatjon'},
#  {'name': 'Velkomin!',
#   'id': 'velkomin',
#   'fastest': 0.0,
#   'shortest': 4,
#   'total': 31353,
#   'acc': 16800,
#   'difficulty': 1.0,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/velkomin'},
#  {'name': 'Viðsnúningur',
#   'id': 'vidsnuningur',
#   'fastest': 0.0,
#   'shortest': 2,
#   'total': 11418,
#   'acc': 5582,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/vidsnuningur'},
#  {'name': 'Weak Vertices',
#   'id': 'weakvertices',
#   'fastest': 0.0,
#   'shortest': 147,
#   'total': 12585,
#   'acc': 7584,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/weakvertices'},
#  {'name': 'WERTYU',
#   'id': 'wertyu',
#   'fastest': 0.0,
#   'shortest': 65,
#   'total': 6271,
#   'acc': 1672,
#   'difficulty': 2.9,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/wertyu'},
#  {'name': 'Which is Greater?',
#   'id': 'whichisgreater',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 26722,
#   'acc': 12752,
#   'difficulty': 1.2,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/whichisgreater'},
#  {'name': "Who's the Boss?",
#   'id': 'whostheboss',
#   'fastest': 0.02,
#   'shortest': 468,
#   'total': 527,
#   'acc': 156,
#   'difficulty': 5.0,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/whostheboss'},
#  {'name': 'Wonky Pizza',
#   'id': 'wonkypizza',
#   'fastest': 0.0,
#   'shortest': 279,
#   'total': 265,
#   'acc': 75,
#   'difficulty': 4.9,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/wonkypizza'},
#  {'name': 'Yin and Yang Stones',
#   'id': 'yinyangstones',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 4416,
#   'acc': 2661,
#   'difficulty': 1.8,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/yinyangstones'},
#  {'name': 'Zamka',
#   'id': 'zamka',
#   'fastest': 0.0,
#   'shortest': 61,
#   'total': 18435,
#   'acc': 10434,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/zamka'},
#  {'name': 'Stand on Zanzibar',
#   'id': 'zanzibar',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 7354,
#   'acc': 4910,
#   'difficulty': 1.4,
#   'category': 'Easy',
#   'link': 'https://open.kattis.com/problems/zanzibar'},
#  {'name': 'Zebras and Ocelots',
#   'id': 'zebrasocelots',
#   'fastest': 0.0,
#   'shortest': 5,
#   'total': 5269,
#   'acc': 1643,
#   'difficulty': 3.3,
#   'category': 'Medium',
#   'link': 'https://open.kattis.com/problems/zebrasocelots'}]

# %%
kt.plot_problems()                          # plot the points distribution

# kt.plot_problems(filepath='plot.png')       # save to a filepath
kt.plot_problems(show_partial=False)        # plot fully solved submissions

# %%
#kt.stats()                                  # your best submission for each problem

#kt.suggest()                                # what's the next problem for me?
kt.achievements()                           # do I have any?
# kt.problem_authors()                        # list down all problem authors
# kt.problem_sources()                        # list down all problem sources

# %%
kt.suggest()

# %%
import kattis
user = kattis.auth(user, password)
